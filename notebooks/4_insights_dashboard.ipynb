# %% [markdown]
# # **Section by Hana : Insights from Dashboard**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **Insights from E-commerce Sales Performance Dashboard**

# %% [markdown]
# ___
# - **Average Review Score:**
#   The average review score is **4.21 out of 5**, indicating a generally positive customer experience and satisfaction with the products and services.
#
# - **On-Time Delivery Rate:**
#   Approximately **91.02% of orders were delivered on time**, showing strong operational efficiency and reliable logistics performance.
#
# - **Total Orders:**
#   A total of **10,090 orders** were processed during the analysis period.
#
# - **Total Revenue:**
#   The platform generated a total revenue of **1.64 million**, reflecting healthy sales performance.
#
# - **Total Sellers:**
#   There were **1,513 unique sellers** active on the platform, contributing to the diverse product offerings.
#   ___

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **Insights from Customer Engagement Dashboard**

# %% [markdown]
# ___
# - **Purchase Frequency:**
#   The average purchase frequency is **1.04**, indicating that most customers are one-time buyers with limited repeat purchases.
#
# - **Average Payment Value:**
#   The average payment value is **139.48**, which gives insight into typical customer spending behavior.
#
# - **Customer Geography:**
#   Most customers are located in **South America**, which aligns with expectations since Olist operates in Brazil.
#
# - **High-Spending Customers:**
#   **65.5% of customers** spend more than half of the average payment value, suggesting a considerable portion are moderate to high spenders.
#
# - **Preferred Payment Method:**
#   **73.53% of customers** prefer to use **credit cards**, highlighting a trend in payment behavior.
#
# - **Product Preferences:**
#   Most customers purchased **health_beauty** products, indicating popularity in personal care categories.
#   ___
